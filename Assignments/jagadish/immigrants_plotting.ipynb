# %% [markdown]
# # Use AustraliaFiltered.xlsx dataset generated earlier.
# - Plot bar chart of total no of immigrants for countires top 5 countires having max no of total immigrants
# - Find total immigrants from each category by area name and plot barchart for each area
# - Plot total immigration trend(immigration of world over the years i.e. year vs Total count for that year) using line plot.
# - Compare Immigration Trend for Asia, Africa and Europe AreaName (Use Line plot).
# - Plot Total Immigrants based on DevelopmenRegion
# - Plot immigration trend for India using line plot
# - Plot immigration Trend(year vs count) for the coutries with top 5 total immigrants. Use Line plot
# - For the above use area plot with alpha = 0.5
# - Compare Immigration Trend for top-5 countires using stacked area plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df= pd.read_excel(r"C:\Users\jaipal\Desktop\dsc_weekday_2020_09_24\Assignments\jagadish\AustraliaFiltered.xlsx",index_col = 0)
df.head()
# Out:
#             Country AreaName           Region             DevName  1980  1981  \
# 224     Afghanistan     Asia    Southern Asia  Developing regions    10    20
# 225         Albania   Europe  Southern Europe   Developed regions     0     0
# 226         Algeria   Africa  Northern Africa  Developing regions    10    50
# 227  American Samoa  Oceania        Polynesia  Developing regions     0     0
# 228         Andorra   Europe  Southern Europe   Developed regions     0     0
#
#      1982  1983  1984  1985  ...  2000  2001  2002  2003  2004  2005  2006  \
# 224    30    30    70   100  ...   100    20    40    70    80   110   180
# 225     0     0     0     0  ...   110   110   200   250   140   130   110
# 226    30    10    20    20  ...    20    30    60    20    20    50    30
# 227     0     0     0    20  ...     0     0     0     0     0     0     0
# 228    10     0     0     0  ...     0    10    10     0    10    10     0
#
#      2007  2008  Total
# 224   140   560   4630
# 225   110   140   1910
# 226    30    60    730
# 227     0    10     30
# 228    10    10    100
#
# [5 rows x 34 columns]

# %%
# Plot bar chart of total no of immigrants for countires top 5 countires having max no of total immigrants
plt.figure(figsize=(15,5))
max_df = df.sort_values(by= 'Total',ascending=False).head()
max_df.plot(x= 'Country',y = 'Total', kind = 'bar')

# %%
# Find total immigrants from each category by area name and plot barchart for each area
grp = df.groupby(['AreaName'])['Total'].sum()
print(grp)
grp.plot(kind = 'bar')
# Out:
# AreaName
# Africa                              354440
# Asia                               3463640
# Europe                             2166780
# Latin America and the Caribbean     120350
# Northern America                    592060
# Oceania                            1126180
# Name: Total, dtype: int64

# %%
# Plot total immigration trend(immigration of world over the years i.e. year vs Total count for that year) using line plot
df1=df.loc[:,'1980':'2008'].sum()
df1.plot.line()

# %%
# Compare Immigration Trend for Asia, Africa and Europe AreaName (Use Line plot).

plt.figure(figsize = (15,5))
asia_df = df[df['AreaName']=='Asia'].loc[:,'1980':'2008'].sum()
asia_df.plot.line()

africa_df = df[df['AreaName']=='Africa'].loc[:,'1980':'2008'].sum()
africa_df.plot.line()

europe_df = df[df['AreaName']=='Europe'].loc[:,'1980':'2008'].sum()
europe_df.plot.line()
plt.legend(['Asia','Africa', 'Europe'])

# %%
# Plot Total Immigrants based on DevelopmenRegion

grp = df.groupby(['DevName'])['Total'].sum()
print(grp)
grp.plot(kind = 'bar')
# Out:
# DevName
# Developed regions     3927800
# Developing regions    3895650
# Name: Total, dtype: int64

# %%
# Plot immigration trend for India using line plot

ind_df = df[df['Country']=='India'].loc[:,'1980':'2008'].sum()
print(ind_df)
ind_df.plot(kind='line')
# Out:
# 1980     1220
# 1981     1560
# 1982     1870
# 1983     2090
# 1984     2300
# 1985     2510
# 1986     2390
# 1987     2900
# 1988     2990
# 1989     2980
# 1990     3930
# 1991     6080
# 1992     5450
# 1993     3350
# 1994     4570
# 1995     6420
# 1996     5780
# 1997     6410
# 1998     7810
# 1999     8370
# 2000    10390
# 2001     9380
# 2002     9240
# 2003    15080
# 2004    18310
# 2005    19920
# 2006    27880
# 2007    41920
# 2008    58400
# dtype: int64

# %%
# Plot immigration Trend(year vs count) for the coutries with top 5 total immigrants. Use Line plot
# Plot immigration Trend(year vs count) for the coutries with top 5 total immigrants. Use Line plot
plt.figure(figsize=(15,5))
top_ctry=list(df.sort_values('Total',ascending=False).head()['Country'])
lists=[df[df['Country']==ctry].loc[:,'1980':'2008'].sum() for ctry in top_ctry]
[i.plot() for i in lists]
plt.legend(top_ctry)
plt.show()
print(top_ctry)
# Out:
# ['United Kingdom of Great Britain and Northern Ireland', 'New Zealand', 'United States of America', 'China, Hong Kong Special Administrative Region', 'China']

# %%
# For the above use area plot with alpha = 0.5
plt.figure(figsize=(15,5))
[i.plot(kind='area',alpha=0.5,stacked=False) for i in lists]

plt.legend(top_ctry)
plt.show()

# %%
# Compare Immigration Trend for top-5 countires using stacked area plot
plt.figure(figsize=(15,5))
[i.plot(kind='area',stacked=True) for i in lists]
plt.show()
